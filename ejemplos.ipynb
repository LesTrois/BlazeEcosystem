# %%
import pandas as pd
from blaze import data,by,join,merge ,concat

# %%
crime = data('crime.csv')
type(crime)
# Out:
# blaze.interactive._Data

# %% [markdown]
# ## Tabla de Crimenes

# %%
crime.head()
# Out:
#    cdatetime              address  district        beat  grid  \
# 0 2006-01-01   3108 OCCIDENTAL DR         3  3C          1115
# 1 2006-01-01  2082 EXPEDITION WAY         5  5A          1512
# 2 2006-01-01           4 PALEN CT         2  2A           212
# 3 2006-01-01       22 BECKFORD CT         6  6C          1443
# 4 2006-01-01     3421 AUBURN BLVD         2  2A           508
# 5 2006-01-01   5301 BONNIEMAE WAY         6  6B          1084
# 6 2006-01-01        2217 16TH AVE         4  4A           957
# 7 2006-01-01            3547 P ST         3  3C           853
# 8 2006-01-01     3421 AUBURN BLVD         2  2A           508
# 9 2006-01-01    1326 HELMSMAN WAY         1  1B           444
#
#                       crimedescr  ucr_ncic_code   latitude   longitude
# 0  10851(A)VC TAKE VEH W/O OWNER           2404  38.550420 -121.391416
# 1     459 PC  BURGLARY RESIDENCE           2204  38.473501 -121.490186
# 2  10851(A)VC TAKE VEH W/O OWNER           2404  38.657846 -121.462101
# 3   476 PC PASS FICTICIOUS CHECK           2501  38.506774 -121.426951
# 4   459 PC  BURGLARY-UNSPECIFIED           2299  38.637448 -121.384613
# 5  530.5 PC USE PERSONAL ID INFO           2604  38.526979 -121.451338
# 6       459 PC  BURGLARY VEHICLE           2299  38.537173 -121.487577
# 7    484 PC   PETTY THEFT/INSIDE           2308  38.564335 -121.461883
# 8      459 PC  BURGLARY BUSINESS           2203  38.637448 -121.384613
# 9        1708 US   THEFT OF MAIL           2310  38.609602 -121.491838

# %% [markdown]
# ## Operación de selección
# En el tabla consultaremos los crimenes que ocurrieron en el distrito 5.

# %%
cd5=crime[crime.district==5]
cd5
# Out:
#              cdatetime                   address  district        beat  grid  \
# 1  2006-01-01 00:00:00       2082 EXPEDITION WAY         5  5A          1512
# 20 2006-01-01 00:01:00          5551 REXLEIGH CT         5  5C          1661
# 24 2006-01-01 00:01:00               15 BASIN CT         5  5C          1654
# 26 2006-01-01 00:01:00         4280 DEER HILL DR         5  5B          1616
# 28 2006-01-01 00:01:00            1816 FLORIN RD         5  5A          1361
# 52 2006-01-01 00:30:00      6571 WEATHERFORD WAY         5  5C          1635
# 57 2006-01-01 00:39:00       7811 DEER MEADOW DR         5  5B          1616
# 66 2006-01-01 01:06:00           4740 BECKET WAY         5  5B          1631
# 67 2006-01-01 01:30:00  CALVINE RD / CENTER PKWY         5  5C          1645
# 68 2006-01-01 01:30:00         6625 VALLEY HI DR         5  5C          1623
# 70 2006-01-01 02:00:00            2500 FLORIN RD         5  5A          1363
#
#                        crimedescr  ucr_ncic_code   latitude   longitude
# 1      459 PC  BURGLARY RESIDENCE           2204  38.473501 -121.490186
# 20       459 PC  BURGLARY VEHICLE           2299  38.446592 -121.442378
# 24                TRAFFIC - I RPT           7000  38.442815 -121.409524
# 26   484G(B) PC ACCESS CARD FRAUD           2605  38.471219 -121.454739
# 28             HARASSMENT - I RPT           7000  38.495353 -121.496560
# 52  10851(A)VC TAKE VEH W/O OWNER           2404  38.466373 -121.426527
# 57   246 PC SHOOT OCCUP DWELL/VEH           5213  38.474000 -121.458193
# 66     459 PC  BURGLARY RESIDENCE           2204  38.465181 -121.446165
# 67  243(D) PC BATT/CIVILIAN W/INJ           1315  38.449721 -121.425872
# 68  10851(A)VC TAKE VEH W/O OWNER           2404  38.471437 -121.427615
# ...

# %% [markdown]
# ## Proyección

# %%
crime[['address','crimedescr','latitude','longitude']].head()
# Out:
#                address                     crimedescr   latitude   longitude
# 0   3108 OCCIDENTAL DR  10851(A)VC TAKE VEH W/O OWNER  38.550420 -121.391416
# 1  2082 EXPEDITION WAY     459 PC  BURGLARY RESIDENCE  38.473501 -121.490186
# 2           4 PALEN CT  10851(A)VC TAKE VEH W/O OWNER  38.657846 -121.462101
# 3       22 BECKFORD CT   476 PC PASS FICTICIOUS CHECK  38.506774 -121.426951
# 4     3421 AUBURN BLVD   459 PC  BURGLARY-UNSPECIFIED  38.637448 -121.384613
# 5   5301 BONNIEMAE WAY  530.5 PC USE PERSONAL ID INFO  38.526979 -121.451338
# 6        2217 16TH AVE       459 PC  BURGLARY VEHICLE  38.537173 -121.487577
# 7            3547 P ST    484 PC   PETTY THEFT/INSIDE  38.564335 -121.461883
# 8     3421 AUBURN BLVD      459 PC  BURGLARY BUSINESS  38.637448 -121.384613
# 9    1326 HELMSMAN WAY        1708 US   THEFT OF MAIL  38.609602 -121.491838

# %% [markdown]
# ## Group by

# %%
by(crime.district,latitude=crime.latitude.mean())
# Out:
#    district   latitude
# 0         1  38.633072
# 1         2  38.623198
# 2         3  38.573090
# 3         4  38.523797
# 4         5  38.473954
# 5         6  38.533416

# %% [markdown]
# ## Join

# %%
join(crime,cd5,'address')
# Out:
#                      address      cdatetime_left  district_left   beat_left  \
# 0        2082 EXPEDITION WAY 2006-01-01 00:00:00              5  5A
# 1           5551 REXLEIGH CT 2006-01-01 00:01:00              5  5C
# 2                15 BASIN CT 2006-01-01 00:01:00              5  5C
# 3          4280 DEER HILL DR 2006-01-01 00:01:00              5  5B
# 4             1816 FLORIN RD 2006-01-01 00:01:00              5  5A
# 5       6571 WEATHERFORD WAY 2006-01-01 00:30:00              5  5C
# 6        7811 DEER MEADOW DR 2006-01-01 00:39:00              5  5B
# 7            4740 BECKET WAY 2006-01-01 01:06:00              5  5B
# 8   CALVINE RD / CENTER PKWY 2006-01-01 01:30:00              5  5C
# 9          6625 VALLEY HI DR 2006-01-01 01:30:00              5  5C
# 10            2500 FLORIN RD 2006-01-01 02:00:00              5  5A
#
#     grid_left                crimedescr_left  ucr_ncic_code_left  \
# 0        1512     459 PC  BURGLARY RESIDENCE                2204
# 1        1661       459 PC  BURGLARY VEHICLE                2299
# 2        1654                TRAFFIC - I RPT                7000
# 3        1616   484G(B) PC ACCESS CARD FRAUD                2605
# 4        1361             HARASSMENT - I RPT                7000
# 5        1635  10851(A)VC TAKE VEH W/O OWNER                2404
# 6        1616   246 PC SHOOT OCCUP DWELL/VEH                5213
# 7        1631     459 PC  BURGLARY RESIDENCE                2204
# 8        1645  243(D) PC BATT/CIVILIAN W/INJ                1315
# 9        1623  10851(A)VC TAKE VEH W/O OWNER                2404
# 10       1363          487(A) PC GRAND THEFT                2303
#
#     latitude_left  longitude_left     cdatetime_right  district_right  \
# 0       38.473501     -121.490186 2006-01-01 00:00:00               5
# 1       38.446592     -121.442378 2006-01-01 00:01:00               5
# 2       38.442815     -121.409524 2006-01-01 00:01:00               5
# 3       38.471219     -121.454739 2006-01-01 00:01:00               5
# 4       38.495353     -121.496560 2006-01-01 00:01:00               5
# 5       38.466373     -121.426527 2006-01-01 00:30:00               5
# 6       38.474000     -121.458193 2006-01-01 00:39:00               5
# 7       38.465181     -121.446165 2006-01-01 01:06:00               5
# 8       38.449721     -121.425872 2006-01-01 01:30:00               5
# 9       38.471437     -121.427615 2006-01-01 01:30:00               5
# 10      38.495710     -121.477826 2006-01-01 02:00:00               5
#
#     beat_right  grid_right               crimedescr_right  \
# 0   5A                1512     459 PC  BURGLARY RESIDENCE
# 1   5C                1661       459 PC  BURGLARY VEHICLE
# 2   5C                1654                TRAFFIC - I RPT
# 3   5B                1616   484G(B) PC ACCESS CARD FRAUD
# 4   5A                1361             HARASSMENT - I RPT
# 5   5C                1635  10851(A)VC TAKE VEH W/O OWNER
# 6   5B                1616   246 PC SHOOT OCCUP DWELL/VEH
# 7   5B                1631     459 PC  BURGLARY RESIDENCE
# 8   5C                1645  243(D) PC BATT/CIVILIAN W/INJ
# 9   5C                1623  10851(A)VC TAKE VEH W/O OWNER
# 10  5A                1363          487(A) PC GRAND THEFT
#
#     ucr_ncic_code_right  latitude_right  longitude_right
# 0                  2204       38.473501      -121.490186
# 1                  2299       38.446592      -121.442378
# 2                  7000       38.442815      -121.409524
# 3                  2605       38.471219      -121.454739
# 4                  7000       38.495353      -121.496560
# 5                  2404       38.466373      -121.426527
# 6                  5213       38.474000      -121.458193
# 7                  2204       38.465181      -121.446165
# 8                  1315       38.449721      -121.425872
# 9                  2404       38.471437      -121.427615
# ...
